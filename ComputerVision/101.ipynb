# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage import measure
from skimage.filters import gaussian
from skimage.feature import canny 
from skimage.color import rgb2gray
from scipy.signal import correlate2d

fig = plt.figure(figsize=(18,6))

ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)

ax2.set_title('Intensity')
coffee = rgb2gray(data.coffee())
coffee = coffee[140:150, 120:140]
ax1.imshow(coffee, plt.cm.gray)
ax2.plot(coffee[0, 0:20])

plt.tight_layout()
plt.show()

# %% [markdown]
# # adding two images together

# %%
fig = plt.figure(figsize=(18,6))

ax1 = plt.subplot(1,2, 1)
ax2 = plt.subplot(1,2, 2)

ax1.set_title('Coffee')
ax2.set_title('Coins')
coins = rgb2gray(data.coins()[0:300, 0:300])
coffee = rgb2gray(data.coffee()[0:300, 0:300])


#concated = np.concatenate((coffee, coins), axis=1)

def blend(img1, img2, ratio):
    return (img1 * ratio) + (img2 * (1 - ratio))

concated = blend(coffee, coins, 0.25)
print(coffee.dtype)
print(coins.dtype)
def difference(img1, img2):
    return measure.compare_psnr(img1, img2)
differ = difference(coffee, coins)


ax1.imshow(coffee, plt.cm.gray)
ax2.imshow(differ, plt.cm.gray)
plt.tight_layout()
plt.show()
# Out:
# float64
# uint8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-b9e3fbc7bb2c> in <module>()
#      21 def difference(img1, img2):
#      22     return measure.compare_psnr(img1, img2)
# ---> 23 differ = difference(coffee, coins)
#      24
#      25
#
# <ipython-input-39-b9e3fbc7bb2c> in difference(img1, img2)
#      20 print(coins.dtype)
#      21 def difference(img1, img2):
# ---> 22     return measure.compare_psnr(img1, img2)
#      23 differ = difference(coffee, coins)
#      24
#
# /Users/necmttn/anaconda3/lib/python3.6/site-packages/skimage/measure/simple_metrics.py in compare_psnr(im_true, im_test, data_range, dynamic_range)
#     117
#     118     """
# --> 119     _assert_compatible(im_true, im_test)
#     120     if dynamic_range is not None:
#     121         warn('`dynamic_range` has been deprecated in favor of '
#
# /Users/necmttn/anaconda3/lib/python3.6/site-packages/skimage/measure/simple_metrics.py in _assert_compatible(im1, im2)
#      14     """Raise an error if the shape and dtype do not match."""
#      15     if not im1.dtype == im2.dtype:
# ---> 16         raise ValueError('Input images must have the same dtype.')
#      17     if not im1.shape == im2.shape:
#      18         raise ValueError('Input images must have the same dimensions.')
#
# ValueError: Input images must have the same dtype.
