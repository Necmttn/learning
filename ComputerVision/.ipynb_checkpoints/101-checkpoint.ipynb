# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.filters import gaussian
from skimage.feature import canny 
from skimage.color import rgb2gray
from scipy.signal import correlate2d

fig = plt.figure(figsize=(18,6))

ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)

ax2.set_title('Intensity')
coffee = rgb2gray(data.coffee())
print(len(coffee[0:20]))
print(len(coffee[40:60]))
coffee = coffee[140:150, 120:140]
print(coffee)
ax1.imshow(coffee, plt.cm.gray)
ax2.plot(coffee[0, 0:20])

plt.tight_layout()
plt.show()
# Out:
# 20
# 20
# [[ 0.26178902  0.25562745  0.25420588  0.25225647  0.25477922  0.25646078
#    0.25898353  0.25870078  0.25926627  0.25506196  0.26318784  0.25898353
#    0.25926627  0.25561255  0.25534471  0.25506196  0.26262235  0.25870078
#    0.25449647  0.25954902]
#  [ 0.26121569  0.25812745  0.25812745  0.25114039  0.25506196  0.25674353
#    0.25926627  0.25142314  0.26207176  0.26934941  0.2629051   0.25926627
#    0.25926627  0.25534471  0.25534471  0.25898353  0.26710941  0.25114039
#    0.26654392  0.25562745]
#  [ 0.26093294  0.25869294  0.25420588  0.25534471  0.24916824  0.25114039
#    0.24329725  0.26262235  0.26654392  0.26233961  0.25841804  0.27438706
#    0.26318784  0.25114039  0.25926627  0.25926627  0.25926627  0.25534471
#    0.26318784  0.25926627]
#  [ 0.25364039  0.25111765  0.26989216  0.25114039  0.25451137  0.26318784
#    0.25114039  0.25534471  0.25506196  0.25506196  0.2629051   0.24329725
#    0.26318784  0.25534471  0.26710941  0.25926627  0.26318784  0.26318784
#    0.26318784  0.26318784]
#  [ 0.26568784  0.24496392  0.25617804  0.26318784  0.26654392  0.25449647
#    0.25534471  0.25114039  0.25114039  0.25506196  0.24750157  0.25534471
#    0.25114039  0.25926627  0.26318784  0.25534471  0.25926627  0.2629051
#    0.26318784  0.26710941]
#  [ 0.26597059  0.25420588  0.25843294  0.26516     0.25898353  0.26710941
#    0.25506196  0.25506196  0.25534471  0.25926627  0.25534471  0.25926627
#    0.25926627  0.25534471  0.25926627  0.25898353  0.26233961  0.26262235
#    0.2629051   0.26318784]
#  [ 0.25703412  0.26794275  0.2606651   0.25983176  0.24805216  0.24329725
#    0.25534471  0.25534471  0.25085765  0.26347059  0.25140824  0.25898353
#    0.25926627  0.25926627  0.25926627  0.25506196  0.27046549  0.26654392
#    0.24776941  0.25422863]
#  [ 0.26207176  0.25534471  0.25702627  0.25926627  0.25926627  0.25114039
#    0.25534471  0.25114039  0.25534471  0.25534471  0.25142314  0.25926627
#    0.25926627  0.24526941  0.25926627  0.25170588  0.25114039  0.26318784
#    0.26516     0.25701137]
#  [ 0.25534471  0.2629051   0.25841804  0.24919098  0.25394588  0.26262235
#    0.25114039  0.25926627  0.25142314  0.26710941  0.25534471  0.25534471
#    0.24301451  0.25506196  0.25168314  0.24134     0.25114039  0.26710941
#    0.27300314  0.26739216]
#  [ 0.26318784  0.25534471  0.25731686  0.24806706  0.25451137  0.26038235
#    0.25142314  0.25142314  0.25926627  0.25114039  0.25142314  0.26318784
#    0.25506196  0.25729412  0.25562745  0.25534471  0.26318784  0.24610275
#    0.26516     0.25675137]]

# %% [markdown]
# # adding two images together

# %%
fig = plt.figure(figsize=(18,6))

ax1 = plt.subplot(1,2, 1)
ax2 = plt.subplot(1,2, 2)

ax1.set_title('Coffee')
ax2.set_title('Coins')
coins = rgb2gray(data.coins()[0:300, 0:300])
coffee = rgb2gray(data.coffee()[0:300, 0:300])



concated = np.concatenate((coffee, coins), axis=1)

ax1.imshow(coffee, plt.cm.gray)
ax2.imshow(concated, plt.cm.gray)
plt.tight_layout()
plt.show()
